# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
happy_2019 = pd.read_csv('happy_2019.csv')

# %%
happy_2019
# Out:
#      Unnamed: 0      Country                           Region  Ladder  \
# 0             0  Switzerland                   Western Europe       6
# 1             1      Iceland                   Western Europe       4
# 2             2      Denmark                   Western Europe       2
# 3             3       Norway                   Western Europe       3
# 4             4       Canada                    North America       9
# ..          ...          ...                              ...     ...
# 145         145       Rwanda               Sub-Saharan Africa     152
# 146         146        Benin               Sub-Saharan Africa     102
# 147         147        Syria  Middle East and Northern Africa     149
# 148         148      Burundi               Sub-Saharan Africa     145
# 149         149         Togo               Sub-Saharan Africa     139
#
#      SD of Ladder  Positive affect  Negative affect  Social support  Freedom  \
# ...

# %% [markdown]
# ## Bubble Plot

# %%
plt.figure(figsize = (10,10))

plt.scatter(x = happy_2019['Ladder'], y = happy_2019['Positive affect'], 
            s = happy_2019['Negative affect'], alpha = 0.5)

plt.xlabel('Ladder')
plt.ylabel('Positive affect')
plt.title('Bubble Plot')
plt.show()

# %%
fig = plt.figure(figsize = (10,10))

plt.scatter(x = happy_2019['Ladder'], y = happy_2019['Positive affect'], 
            s = happy_2019['Negative affect'], alpha = 0.5, c = happy_2019['Social support']) #c = color

plt.xlabel('Ladder')
plt.ylabel('Positive Affect')
plt.title('Bubble Plot')

# menambah warna

ax_col = fig.add_axes([0.99, 0.3, 0.05, 0.3])
ax_col.set_title('Social Support Color Bar')
plt.colorbar(cax = ax_col)
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize = (12,12))

sns.boxplot(data = happy_2019, x = 'Ladder', y= 'Region')
sns.swarmplot(data = happy_2019, x = 'Ladder', y= 'Region')

# %% [markdown]
# ## Latihan

# %% [markdown]
# 1. What features that seems to be consistently affecting the ladder score ? Why ?
# 2. Is there a relationship between the region and the ladder score ?
# 3. Can you find any relationship between numerical features other than the ladder score and the SD ladder score ? Why ?

# %%
plt.figure(figsize = (10,10))
sns.heatmap(happy_2019.corr()[['Ladder']], annot = True)

# %% [markdown]
# From data on heatmap above, we can see that many factors seems to correlate and might affect the Ladder score. First there is Social Support with 0.82 points, then there is Log of GDP Per Capita and Healthy Life Expectancy features with 0.81 points respectively. This might indicates that there is a strong posistive connection between those variables. While SD of Ladder, Positive affect, Negative affect and Freedom might also have a correlation, yet from the score above we might not see a strong connections as they only have a values of 0.52 to 0.55. Also, below we'll try to visualize the data between variables to further see the correlations.

# %%
plt.scatter(x = happy_2019['Ladder'], y = happy_2019['Social support'])

# %%
plt.scatter(x = happy_2019['Ladder'], y = happy_2019['Log of GDP\nper capita'])

# %%
plt.scatter(x = happy_2019['Ladder'], y = happy_2019['Healthy life\nexpectancy'])

# %%
happy_2019.sort_values(by = 'Ladder')[['Region', 'Ladder']]
# Out:
#                               Region  Ladder
# 5                     Western Europe       1
# 2                     Western Europe       2
# 3                     Western Europe       3
# 1                     Western Europe       4
# 6                     Western Europe       5
# ..                               ...     ...
# 128  Middle East and Northern Africa     151
# 145               Sub-Saharan Africa     152
# 137               Sub-Saharan Africa     153
# 144                    Southern Asia     154
# 139               Sub-Saharan Africa     155
#
# [150 rows x 2 columns]
